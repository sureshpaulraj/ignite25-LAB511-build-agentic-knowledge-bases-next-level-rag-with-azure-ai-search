# %% [markdown]
# # Part 8: Medium Knowledge Base
#
# In Part 7, you experienced minimal reasoning effort optimized for speed and cost. In this part, we introduce **medium reasoning effort**, the highest level of effort currently available. This effort adds on a retrieval step when it determines the original results were not optimal.
#
# ## Step 1: Load Environment Variables
#
# Run below cell to load the configuration for your Azure resources, choose the **.venv(3.11.9)** environment that is created for you.
#
# This time you'll create a knowledge base with balanced reasoning capabilities.
#
# > **⚠️ Troubleshooting**
# >
# > If code cells get stuck and keep spinning, select **Restart** from the notebook toolbar at the top. If the issue persists after a couple of tries, close VS Code completely and reopen it.

# %%
import os

from azure.core.credentials import AzureKeyCredential
from dotenv import load_dotenv

load_dotenv(override=True) # take environment variables from .env.

# Azure AI Search configuration
endpoint = os.environ["AZURE_SEARCH_SERVICE_ENDPOINT"]
credential = AzureKeyCredential(os.environ["AZURE_SEARCH_ADMIN_KEY"])

# Knowledge base name
knowledge_base_name = "medium-knowledge-base"

# Azure OpenAI configuration (identity-based auth, no API key needed)
azure_openai_endpoint = os.environ["AZURE_OPENAI_ENDPOINT"]
azure_openai_chatgpt_deployment = os.getenv("AZURE_OPENAI_CHATGPT_DEPLOYMENT", "gpt-4.1")
azure_openai_chatgpt_model_name = os.getenv("AZURE_OPENAI_CHATGPT_MODEL_NAME", "gpt-4.1")

print("Environment variables loaded")
# Out:
# Environment variables loaded

# %% [markdown]
# ## Step 2: Create Medium Reasoning Knowledge Base
#
# The code below creates a knowledge base using `KnowledgeRetrievalMediumReasoningEffort`. Unlike minimal reasoning, this configuration includes Azure OpenAI for moderate query decomposition and answer synthesis.
#
# Medium reasoning brings back the Azure OpenAI model to enable query planning and answer synthesis, while using `ANSWER_SYNTHESIS` output mode to return synthesized answers instead of raw chunks. The configuration also includes retrieval instructions that guide source selection with natural language.
#
# This balanced approach provides better reasoning capabilities than minimal effort while maintaining reasonable performance and cost efficiency.

# %%
from azure.search.documents.indexes import SearchIndexClient
from azure.search.documents.indexes.models import AzureOpenAIVectorizerParameters, KnowledgeBase, KnowledgeBaseAzureOpenAIModel, KnowledgeRetrievalMediumReasoningEffort, KnowledgeRetrievalOutputMode, KnowledgeSourceReference, WebKnowledgeSource

index_client = SearchIndexClient(endpoint=endpoint, credential=credential)

# Using identity-based auth: the search service's system-assigned managed identity
# authenticates to Azure OpenAI (no api_key needed)
aoai_params = AzureOpenAIVectorizerParameters(
    resource_url=azure_openai_endpoint,
    deployment_name=azure_openai_chatgpt_deployment,
    model_name=azure_openai_chatgpt_model_name,
)

ks = WebKnowledgeSource(
    name="web-knowledge-source",
    description="Knowledge source for Web"
)
index_client.create_or_update_knowledge_source(knowledge_source=ks)
print(f"Knowledge source '{ks.name}' created or updated successfully.")

knowledge_base = KnowledgeBase(
    name=knowledge_base_name,
    models=[KnowledgeBaseAzureOpenAIModel(azure_open_ai_parameters=aoai_params)],
    knowledge_sources=[
        KnowledgeSourceReference(name="hrdocs-knowledge-source"),
        KnowledgeSourceReference(name="web-knowledge-source"),
    ],
    output_mode=KnowledgeRetrievalOutputMode.ANSWER_SYNTHESIS,
    retrieval_reasoning_effort=KnowledgeRetrievalMediumReasoningEffort(),
    retrieval_instructions="Always search hrdocs first, then web if needed."
)

index_client.create_or_update_knowledge_base(knowledge_base)
print(f"Knowledge base '{knowledge_base_name}' created or updated successfully.")
# Out:
# Knowledge source 'web-knowledge-source' created or updated successfully.
# Knowledge base 'medium-knowledge-base' created or updated successfully.

# %% [markdown]
# ## Step 3: Query Complex Multi-Step Question
#
# The query below demonstrates medium reasoning capabilities with a complex question that requires multiple steps: finding when Zava launched a handheld product, determining the zodiac sign for that year, and describing the product.
#
# This type of multi-step reasoning showcases how medium effort balances sophisticated query decomposition with performance optimization.

# %%
from azure.search.documents.knowledgebases import KnowledgeBaseRetrievalClient
from azure.search.documents.knowledgebases.models import KnowledgeBaseMessage, KnowledgeBaseMessageTextContent, KnowledgeBaseRetrievalRequest, SearchIndexKnowledgeSourceParams, WebKnowledgeSourceParams
from IPython.display import display, Markdown

knowledge_base_client = KnowledgeBaseRetrievalClient(endpoint=endpoint, knowledge_base_name=knowledge_base_name, credential=credential)
web_ks_params = WebKnowledgeSourceParams(
    knowledge_source_name="web-knowledge-source",
    include_references=True,
    include_reference_source_data=True
)
hrdocs_ks_params = SearchIndexKnowledgeSourceParams(
    knowledge_source_name="hrdocs-knowledge-source",
    include_references=True,
    include_reference_source_data=True
)
req = KnowledgeBaseRetrievalRequest(
    messages=[
        KnowledgeBaseMessage(role="user", content=[KnowledgeBaseMessageTextContent(text="""
            Zava was founded in 1985 by visionary entrepreneurs
            In one particular year, they launched a groundbreaking product that revolutionized the industry that you could hold in your hands
            Name the Chinese Zodiac sign for that year and describe the product that was launched.                         
        """)])
    ],
    knowledge_source_params=[
        web_ks_params, hrdocs_ks_params
    ],
    include_activity=True
)

result = knowledge_base_client.retrieve(retrieval_request=req)
display(Markdown(result.response[0].content[0].text))
# Out:
# In 1990, Zava launched the first-ever handheld personal computer, a groundbreaking product that revolutionized the industry by allowing users to carry computing power in their hands [ref_id:0]. The Chinese Zodiac sign for 1990 is the Horse, specifically the Metal Horse, which symbolizes energy, determination, and progress [ref_id:1][ref_id:2][ref_id:3][ref_id:5].

# %% [markdown]
# ## Step 4: Review References and Citations
#
# Let's check out the references used to construct the answer. Medium reasoning effort provides detailed citations while balancing retrieval thoroughness with efficiency.

# %%
import json

references = json.dumps([ref.as_dict() for ref in result.references], indent=2)
print(references)
# Out:
# [
#   {
#     "type": "searchIndex",
#     "id": "0",
#     "activity_source": 1,
#     "source_data": {
#       "uid": "810256edf976_aHR0cHM6Ly9tYWdvdHRlaWFkbHNnZW4yLmJsb2IuY29yZS53aW5kb3dzLm5ldC9sYWJkb2NzL1phdmFfQ29tcGFueV9PdmVydmlldy5tZA2_pages_0",
#       "blob_path": "/hrdocs/Zava_Company_Overview.md",
#       "snippet": "# Zava\r\n\r\n*Disclaimer: This content is generated by AI and may not accurately represent factual information about any real entity. Use this information with caution and verify details from reliable sources.*\r\n\r\n## History\r\n\r\nZava, a pioneering force in the industry, was founded in 1985 by visionary entrepreneurs with a passion for innovation. Over the years, the company has played a pivotal role in shaping the landscape of consumer electronics.\r\n\r\n| Year | Milestone |\r\n|------|-----------|\r\n| 1985 | Company founded with a focus on cutting-edge technology |\r\n| 1990 | Launched the first-ever handheld personal computer |\r\n| 2000 | Introduced groundbreaking advancements in AI and robotics |\r\n| 2015 | Expansion into sustainable and eco-friendly product lines |\r\n\r\n## Company Overview\r\n\r\nAt Zava, we take pride in fostering a dynamic and inclusive workplace. Our dedicated team of experts collaborates to create innovative solutions that empower and connect people globally.\r\n\r\n### Core Values\r\n\r\n- **Innovation:** Constantly pushing the boundaries of technology.\r\n- **Diversity:** Embracing different perspectives for creative excellence.\r\n- **Sustainability:** Committed to eco-friendly practices in our products.\r\n\r\n## Vacation Perks\r\n\r\nWe believe in work-life balance and understand the importance of well-deserved breaks. Our vacation perks are designed to help our employees recharge and return with renewed enthusiasm.\r\n\r\n| Vacation Tier | Duration | Additional Benefits |\r\n|---------------|----------|---------------------|\r\n| Standard      | 2 weeks  | Health and wellness stipend |\r\n| Senior        | 4 weeks  | Travel vouchers for a dream destination |\r\n| Executive     | 6 weeks  | Luxury resort getaway with family |\r\n\r\n## Employee Recognition\r\n\r\nRecognizing the hard work and dedication of our employees is at the core of our culture. Here are some ways we celebrate achievements:\r\n\r\n- Monthly \"Innovator of the Month\" awards"
#     },
#     "reranker_score": 3.0130727,
#     "doc_key": "810256edf976_aHR0cHM6Ly9tYWdvdHRlaWFkbHNnZW4yLmJsb2IuY29yZS53aW5kb3dzLm5ldC9sYWJkb2NzL1phdmFfQ29tcGFueV9PdmVydmlldy5tZA2_pages_0"
#   },
#   {
#     "type": "web",
#     "id": "1",
#     "activity_source": 10,
#     "source_data": {
#       "url": "https://www.sohoinchina.com/1990-is-what-chinese-zodiac/",
#       "title": "1990 Chinese Zodiac Explained: Year of the Metal Horse Guide"
#     },
#     "url": "https://www.sohoinchina.com/1990-is-what-chinese-zodiac/",
#     "title": "1990 Chinese Zodiac Explained: Year of the Metal Horse Guide"
#   },
#   {
#     "type": "web",
#     "id": "2",
#     "activity_source": 10,
#     "source_data": {
#       "url": "https://www.famousbirthdays.com/zodiac/1990.html",
#       "title": "1990 Chinese Zodiac | Metal Horse | Famous Birthdays"
#     },
#     "url": "https://www.famousbirthdays.com/zodiac/1990.html",
#     "title": "1990 Chinese Zodiac | Metal Horse | Famous Birthdays"
#   },
#   {
#     "type": "web",
#     "id": "3",
#     "activity_source": 10,
#     "source_data": {
#       "url": "https://www.lingoace.com/blog/1990-chinese-zodiac/",
#       "title": "1990 Chinese Zodiac: Horse Personality, Career and Compatibility"
#     },
#     "url": "https://www.lingoace.com/blog/1990-chinese-zodiac/",
#     "title": "1990 Chinese Zodiac: Horse Personality, Career and Compatibility"
#   },
#   {
#     "type": "web",
#     "id": "4",
#     "activity_source": 10,
#     "source_data": {
#       "url": "https://astrologyk.com/zodiac/chinese/year/1990",
#       "title": "1990 Chinese Zodiac \u2013 Metal Horse Year - Astrology"
#     },
#     "url": "https://astrologyk.com/zodiac/chinese/year/1990",
#     "title": "1990 Chinese Zodiac \u2013 Metal Horse Year - Astrology"
#   },
#   {
#     "type": "web",
#     "id": "5",
#     "activity_source": 10,
#     "source_data": {
#       "url": "https://www.chineseastrologyyear.com/archives/25035",
#       "title": "Year of the Horse 1990: A Complete Analysis"
#     },
#     "url": "https://www.chineseastrologyyear.com/archives/25035",
#     "title": "Year of the Horse 1990: A Complete Analysis"
#   },
#   {
#     "type": "web",
#     "id": "6",
#     "activity_source": 10,
#     "source_data": {
#       "url": "https://www.chineseastrologyyear.com/archives/26214",
#       "title": "All You Need to Know About 1990 Chinese Animal"
#     },
#     "url": "https://www.chineseastrologyyear.com/archives/26214",
#     "title": "All You Need to Know About 1990 Chinese Animal"
#   },
#   {
#     "type": "web",
#     "id": "7",
#     "activity_source": 10,
#     "source_data": {
#       "url": "https://www.sohoinchina.com/1990-horoscope-chinese/",
#       "title": "1990 Chinese Horoscope Guide: The Year of the Metal Horse"
#     },
#     "url": "https://www.sohoinchina.com/1990-horoscope-chinese/",
#     "title": "1990 Chinese Horoscope Guide: The Year of the Metal Horse"
#   },
#   {
#     "type": "web",
#     "id": "8",
#     "activity_source": 10,
#     "source_data": {
#       "url": "https://www.sohoinchina.com/year-1990/",
#       "title": "Chinese Year 1990: Meaning and Traits of the Metal Horse"
#     },
#     "url": "https://www.sohoinchina.com/year-1990/",
#     "title": "Chinese Year 1990: Meaning and Traits of the Metal Horse"
#   },
#   {
#     "type": "web",
#     "id": "9",
#     "activity_source": 10,
#     "source_data": {
#       "url": "https://astrologyinaction.com/chinese-astrology-1990",
#       "title": "Chinese Astrology 1990"
#     },
#     "url": "https://astrologyinaction.com/chinese-astrology-1990",
#     "title": "Chinese Astrology 1990"
#   },
#   {
#     "type": "web",
#     "id": "10",
#     "activity_source": 10,
#     "source_data": {
#       "url": "https://takemeback.to/chinese-horoscope/date/1990",
#       "title": "Chinese Zodiac Sign for 1990: Characteristics and Meaning"
#     },
#     "url": "https://takemeback.to/chinese-horoscope/date/1990",
#     "title": "Chinese Zodiac Sign for 1990: Characteristics and Meaning"
#   }
# ]

# %% [markdown]
# ## Step 5: Analyze Reasoning Activity
#
# Run the cell below to view the activity log that reveals how medium reasoning effort processed your complex query. You'll see evidence of query decomposition, source selection based on retrieval instructions, and the reasoning steps taken to synthesize the final answer.

# %%
import pandas as pd

activity_types = [{"type": a.type} for a in result.activity]

df = pd.DataFrame(activity_types)

print("Activity Log Steps")
df
# Out:
# Activity Log Steps
#                     type
# 0     modelQueryPlanning
# 1            searchIndex
# 2            searchIndex
# 3            searchIndex
# 4            searchIndex
# 5                    web
# 6                    web
# 7                    web
# 8                    web
# 9     modelQueryPlanning
# 10                   web
# 11      agenticReasoning
# 12  modelAnswerSynthesis

# %%
activity_content = json.dumps([a.as_dict() for a in result.activity], indent=2)
print("Activity Details")
print(activity_content)
# Out:
# Activity Details
# [
#   {
#     "id": 0,
#     "type": "modelQueryPlanning",
#     "elapsed_ms": 1626,
#     "input_tokens": 2183,
#     "output_tokens": 177
#   },
#   {
#     "id": 1,
#     "type": "searchIndex",
#     "elapsed_ms": 228,
#     "knowledge_source_name": "hrdocs-knowledge-source",
#     "query_time": "2026-02-20T04:25:27.447Z",
#     "count": 9,
#     "search_index_arguments": {
#       "search": "Zava product launches by year, especially handheld products that revolutionized the industry",
#       "source_data_fields": [
#         {
#           "name": "snippet"
#         },
#         {
#           "name": "uid"
#         },
#         {
#           "name": "blob_path"
#         }
#       ],
#       "search_fields": [
#         {
#           "name": "snippet"
#         }
#       ],
#       "semantic_configuration_name": "semantic-configuration"
#     }
#   },
#   {
#     "id": 2,
#     "type": "searchIndex",
#     "elapsed_ms": 1423,
#     "knowledge_source_name": "hrdocs-knowledge-source",
#     "query_time": "2026-02-20T04:25:28.871Z",
#     "count": 1,
#     "search_index_arguments": {
#       "search": "Year in which Zava launched a groundbreaking handheld product",
#       "source_data_fields": [
#         {
#           "name": "snippet"
#         },
#         {
#           "name": "uid"
#         },
#         {
#           "name": "blob_path"
#         }
#       ],
#       "search_fields": [
#         {
#           "name": "snippet"
#         }
#       ],
#       "semantic_configuration_name": "semantic-configuration"
#     }
#   },
#   {
#     "id": 3,
#     "type": "searchIndex",
#     "elapsed_ms": 256,
#     "knowledge_source_name": "hrdocs-knowledge-source",
#     "query_time": "2026-02-20T04:25:29.128Z",
#     "count": 1,
#     "search_index_arguments": {
#       "search": "Chinese Zodiac sign for the year Zava launched the groundbreaking handheld product",
#       "source_data_fields": [
#         {
#           "name": "snippet"
#         },
#         {
#           "name": "uid"
#         },
#         {
#           "name": "blob_path"
#         }
#       ],
#       "search_fields": [
#         {
#           "name": "snippet"
#         }
#       ],
#       "semantic_configuration_name": "semantic-configuration"
#     }
#   },
#   {
#     "id": 4,
#     "type": "searchIndex",
#     "elapsed_ms": 345,
#     "knowledge_source_name": "hrdocs-knowledge-source",
#     "query_time": "2026-02-20T04:25:29.474Z",
#     "count": 2,
#     "search_index_arguments": {
#       "search": "Description of the groundbreaking handheld product launched by Zava",
#       "source_data_fields": [
#         {
#           "name": "snippet"
#         },
#         {
#           "name": "uid"
#         },
#         {
#           "name": "blob_path"
#         }
#       ],
#       "search_fields": [
#         {
#           "name": "snippet"
#         }
#       ],
#       "semantic_configuration_name": "semantic-configuration"
#     }
#   },
#   {
#     "id": 5,
#     "type": "web",
#     "elapsed_ms": 411,
#     "knowledge_source_name": "web-knowledge-source",
#     "query_time": "2026-02-20T04:25:29.474Z",
#     "count": 7,
#     "web_arguments": {
#       "search": "Zava product launches by year, especially handheld products that revolutionized the industry"
#     }
#   },
#   {
#     "id": 6,
#     "type": "web",
#     "elapsed_ms": 443,
#     "knowledge_source_name": "web-knowledge-source",
#     "query_time": "2026-02-20T04:25:30.014Z",
#     "count": 14,
#     "web_arguments": {
#       "search": "Year in which Zava launched a groundbreaking handheld product"
#     }
#   },
#   {
#     "id": 7,
#     "type": "web",
#     "elapsed_ms": 416,
#     "knowledge_source_name": "web-knowledge-source",
#     "query_time": "2026-02-20T04:25:30.528Z",
#     "count": 17,
#     "web_arguments": {
#       "search": "Chinese Zodiac sign for the year Zava launched the groundbreaking handheld product"
#     }
#   },
#   {
#     "id": 8,
#     "type": "web",
#     "elapsed_ms": 353,
#     "knowledge_source_name": "web-knowledge-source",
#     "query_time": "2026-02-20T04:25:31.047Z",
#     "count": 10,
#     "web_arguments": {
#       "search": "Description of the groundbreaking handheld product launched by Zava"
#     }
#   },
#   {
#     "id": 9,
#     "type": "modelQueryPlanning",
#     "elapsed_ms": 1338,
#     "input_tokens": 4192,
#     "output_tokens": 165
#   },
#   {
#     "id": 10,
#     "type": "web",
#     "elapsed_ms": 437,
#     "knowledge_source_name": "web-knowledge-source",
#     "query_time": "2026-02-20T04:25:33.093Z",
#     "count": 30,
#     "web_arguments": {
#       "search": "Chinese Zodiac sign for the year 1990"
#     }
#   },
#   {
#     "id": 11,
#     "type": "agenticReasoning",
#     "reasoning_tokens": 139447,
#     "retrieval_reasoning_effort": {
#       "kind": "medium"
#     }
#   },
#   {
#     "id": 12,
#     "type": "modelAnswerSynthesis",
#     "elapsed_ms": 1478,
#     "input_tokens": 6580,
#     "output_tokens": 96
#   }
# ]

# %% [markdown]
# ## Summary
#
# You've now experienced medium reasoning knowledge bases that balance sophisticated reasoning capabilities with performance optimization.
#
# **Key concepts to remember:**
# - `KnowledgeRetrievalMediumReasoningEffort` balances reasoning sophistication with performance
# - Azure OpenAI model enables moderate query decomposition and answer synthesis
# - `ANSWER_SYNTHESIS` output mode provides synthesized answers with proper citations
# - `retrieval_instructions` guide source selection (hrdocs first, then web if needed)
# - Complex multi-step queries demonstrate medium reasoning's capability to handle sophisticated information needs
#
# ### What's Next?
#
# 🎉 **Congratulations!** You've completed all 8 parts of the LAB511 Knowledge Bases workshop. You now understand the full spectrum of Azure AI Search Knowledge Bases from basic single-source queries to optimized reasoning strategies.
#
# - Clone and Star our [repo](https://github.com/microsoft/ignite25-LAB511-build-agentic-knowledge-bases-next-level-rag-with-azure-ai-search) to explore further.
# - Check out [Azure AI Search docs](https://learn.microsoft.com/en-us/azure/search/) for more information.
# - Share your feedback for this lab!
#
# You are now ready to build advanced agentic knowledge bases tailored to your specific needs using Azure AI Search!
